# %%
# %matplotlib inline

# %%
# %matplotlib inline
import scipy.io as sio
import numpy 
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))
sns.set(color_codes=True)

np.random.seed(sum(map(ord, "distributions")))



pre_label_before = sio.loadmat('/home/lein/yan/caffe/finetunning_thesis/mirroring/code/pred_label_original.mat')
pre_label_after_PIC = sio.loadmat('/home/lein/yan/caffe/finetunning_thesis/argu_par_ic/1fold/code/pred_label_par_IC.mat')

print pre_label_before.keys()
pre_label_before = pre_label_before['C']
pre_label_after_PIC = pre_label_after_PIC['C']
print pre_label_before.shape
print pre_label_after_PIC.shape
pre_label_after_PIC
# Out:
# ['C', '__version__', '__header__', '__globals__']
# (163273, 2)
# (163095, 2)
# array([[  5.25604439,   5.        ],
#        [  5.72798204,   5.        ],
#        [  5.0492835 ,   5.        ],
#        ...,
#        [ 10.        ,  10.        ],
#        [  9.67400169,  10.        ],
#        [  9.88965225,  10.        ]], dtype=float32)

# %%
# Out:
# (768913, 2)

# %%
label_all = pre_label_after_PIC[:,1]
pred_after_PIC= pre_label_after_PIC[:,0]
type(label_all)
sns.distplot(label_all)

# %%
sns.distplot(pred_after_PIC)

# %%
pred_before = pre_label_before[:,0]
sns.distplot(pred_before)
